# %% [markdown]
# # Выявление абонентов с двумя сим-картами в сети МФ
#
# ## Задача.
# Определить абонентов (msisdn), которые являются одной и той же Персоной (человеком)/
# Нужно построить классификацию, определяющую является ли пара msisdn принадлижайшей одной Персоне.
#
# ## Метрика.
# Для оценки качества используется метрика $F1$, так как классы несбалансированы.
# $$F1 = 2\frac{Precission * Recall}{Precission + Recall}$$
#
# ## План.
# * Определение целевого события
# * Описание идеи алгоритма
# * Анализ данных
# * Формирование фичей
# * Построение моделей
# * Предсказание

# %%
# !pip install ipynb
import pandas as pd
import os
from os import walk
import datetime
pd.set_option('display.max_columns', 500)

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from datetime import datetime, date

import csv

import folium
from folium import plugins
from folium.plugins import HeatMap
import branca
import branca.colormap as cm

from ipynb.fs.full.persona_msisdn_functions import *
# Out:
# Requirement already satisfied: ipynb in c:\users\ekaterina.adischeva\appdata\local\continuum\anaconda3\lib\site-packages (0.5.1)

# %% [markdown]
# ## Определение целевого события
#
# Рассматриваем неупорядоченные пары номеров телефонов (пары без повторений и не важен порядок, в котором указаны телефоны).
#
# Если пара номеров принадлежит одной Персоне, то целевое событие равно 1, если разным Персонам, то 0.
#
# В файле 02_Факты для некоторых пар указано, что они принадлежат одной Персоне.
#
# ### Генерируем дополнительные пары, которые не принадлежат одной Персоне.
# Считаем, что вероятность того, что у Персоны 3 и более телефонов небольшая и этим событием можно принебречь. Тогда любая пара телефонов, у которой первый msisdn из файла 02_Факты, а второй msisdn не совподает с указанным номером-парой для первого телефона, не принадлежит одной Персоне.
#
# Пара номеров телефонов не принадлежит одной Персоне с вероятьностью более $1 - \frac{2}{n-1}$. Добавдяем в выборку для построения моделей пары номеров, у которых каждый номер не принадлежит файлу 02_Факты.

# %% [markdown]
# ## Идея алгоритма
#
# Один из способов понять, принадлежат ли телефоны одной Персоне, это изучение движения номеров.
# Для номеров одной персоны движения должны быть "похожими".
#
# Так как пложение абонентов регистрируется в случайные моменты времени, у нас нет достоверной информации где находится абонент в каждый момент времени, поэтому рассчитать точное расстояние между телефонами невозможно.
#
# Чтобы оценить расстояние между телефонами мы приблизительно определяем положение абноента в нужные для нас моменты времени.

# %% [markdown]
# ## Анализ данных

# %%
# загружаем данные
current_directory = r'C:\Users\ekaterina.adischeva\Documents\Scripts\BD_task\Техническое задание_аналитик больших данных\Данные'
current_directory = current_directory.replace('\\','/')
os.chdir(current_directory)

df_data = pd.read_csv('02_Data.csv', sep = ';', dtype = {'imei': str, 'lac' : 'str', 'cid' : 'str'})
facts = pd.read_excel('01_Факты.xlsx', header = None)
tac_dict = pd.read_csv('03_устройства.csv', quoting=csv.QUOTE_NONE)
event_type = pd.read_excel('04_event_type.xlsx')

# %% [markdown]
# 2 абонента из пар не попали в выборку с детальными данными. Ничего с этим не делаем.

# %%
# for 2 persons we don't have second msisdn in our dataset
display(facts[~facts[1].isin(df_data['msisdn'])], 
        facts[~facts[0].isin(df_data['msisdn'])])
# Out:
#                0             1
# 1   158510912201  158528852857
# 17  158528850493  158530004641
# Empty DataFrame
# Columns: [0, 1]
# Index: []

# %%
# Оцениваем пустые данные в датафрейм. Отсутсвуют данные по imei и моделям телефона.
df_data.shape[0] - df_data.count()
# Out:
# lac                0
# cid                0
# msisdn             0
# imei           11588
# event_type         0
# tstamp             0
# long               0
# lat                0
# max_dist           0
# cell_type          0
# start_angle        0
# end_angle          0
# dtype: int64

# %%
# заполняю пустые значения imei самым популярным значением для абонента
msisdn_imei_count = df_data[~df_data['imei'].isna()].groupby(['msisdn', 'imei'])['lac'].count().reset_index().sort_values('lac', ascending = False)
msisdn_imei_count['K'] = msisdn_imei_count.groupby('msisdn')['imei'].cumcount()
msisdn_imei_count = msisdn_imei_count[msisdn_imei_count['K'] == 0][['msisdn', 'imei']].rename(columns = {'imei':'imei_pop'})
print(df_data['msisdn'].nunique(), msisdn_imei_count.shape[0])
df_data = df_data.merge(msisdn_imei_count, on = ['msisdn'], how = 'left')
df_data['imei'] = df_data['imei'].fillna(df_data['imei_pop'])
df_data.drop(columns = ['imei_pop'], inplace = True)
df_data.shape[0] - df_data.count()
# Out:
# 2361 2359
# lac            0
# cid            0
# msisdn         0
# imei           5
# event_type     0
# tstamp         0
# long           0
# lat            0
# max_dist       0
# cell_type      0
# start_angle    0
# end_angle      0
# dtype: int64

# %%
# Преобразовываем данные в удобный формат
tac_dict.columns = tac_dict.columns.str.replace('\"','')
for column_name in tac_dict.columns:
    tac_dict[column_name] = tac_dict[column_name].str.replace('\"','')

# Конвертирую время
df_data['datetime'] = pd.to_timedelta(df_data['tstamp']/1000, unit='S') + pd.Timestamp('1970-1-1')
df_data['datetime'] = pd.to_datetime(df_data['datetime'])

# %%
# Объединяем данные в один датафрейм
df_data = df_data.merge(event_type, left_on = ['event_type'], right_on = 'Номер', how = 'left')

# %% [markdown]
# ## Анализ параметров, связанных с моделью телефона
# Строим массив *msisdn_device*, в котором для каждого абонента указываем инфомрацию о модели телефона
# * кол-во используемых аппаратов
# * imei самого популярного аппарата
# * Платформа
# * Индикатор, что Платформа попадает в TOP 5
# * Производитель
# * Индикатор, что Производитель попадает в TOP 10
# * Тип устройства

# %%
msisdn_imei_qnt = df_data.groupby(['msisdn'])['imei'].nunique().reset_index()
msisdn_imei_qnt.set_index('msisdn', inplace = True)
msisdn_imei_count.set_index('msisdn', inplace = True)
msisdn_device = pd.concat([msisdn_imei_qnt, msisdn_imei_count], axis = 1).reset_index()

msisdn_device['tac'] = msisdn_device['imei_pop'].str.slice(0,8)
msisdn_device = msisdn_device.merge(tac_dict, on = ['tac'], how = 'left')

# %%
TOP_VENDOR = 10
TOP_PLATFORM = 5
TOP_TYPE = 5

top_vendors_list = msisdn_device['vendor'].value_counts().head(TOP_VENDOR).index
top_platforms_list = msisdn_device['platform'].value_counts().head(TOP_PLATFORM).index
top_type_list = msisdn_device['platform'].value_counts().head(TOP_TYPE).index

# %%
sns.countplot(msisdn_device['type'])
# Out:
# C:\Users\ekaterina.adischeva\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
msisdn_device['vendor'] = np.where(msisdn_device['vendor'].isin(top_vendors_list), msisdn_device['vendor'], 'Other')
msisdn_device['platform'] = np.where(msisdn_device['platform'].isin(top_platforms_list), msisdn_device['platform'], 'Other')
msisdn_device['type'] = np.where(msisdn_device['type'].isin(top_type_list), msisdn_device['type'], 'Other')
msisdn_device.drop(columns = 'tac', inplace = True)

# %% [markdown]
# ## Анализ времени
#
# Смотрим распределение событий по времени, чтобы убрать данные, коотрые попали в таблицу по ошибке. Убираем события, произошедшие после 26 мая 2013.
# События 22 мая оставляем, так как их распределние по времени похоже на распредления в другие дни.

# %%
plt.hist(df_data['datetime'].values, bins=100)
plt.xticks(rotation=70)
plt.show()
# Out:
# C:\Users\ekaterina.adischeva\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %%
df_data.loc[:, 'date'] = df_data['datetime'].dt.date
print(df_data['date'].value_counts())
df_data = df_data[(df_data['datetime']  < datetime.strptime('2013-05-26', '%Y-%m-%d'))
         #         & (df_data['datetime']  >= datetime.strptime('2013-05-23', '%Y-%m-%d'))
                 ]
# Out:
# 2013-05-24    61642
# 2013-05-23    59463
# 2013-05-25    48519
# 2013-05-22     4450
# 2013-05-29       24
# 2013-05-28       18
# 2013-05-30        7
# Name: date, dtype: int64

# %% [markdown]
# ## Анализ координат
# Проверяем расположение и параметры базовых станций

# %%
CENTER_LAT, CENTER_LONG = 55.7522200, 37.6155600
m = folium.Map(location=(CENTER_LAT, CENTER_LONG))
show_circles_on_map(m, df_data.sample(500), "lat", "long", "blue")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Смотрим распределение базовых станций по углам действия

# %%
df_data['angle'] = np.where(df_data['end_angle'] < df_data['start_angle'], df_data['end_angle'] - df_data['start_angle'] + 360,
                        df_data['end_angle'] - df_data['start_angle'])
sns.countplot(df_data['angle'])
df_data['angle'].value_counts()
# Out:
# C:\Users\ekaterina.adischeva\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# 60.0     156940
# 47.0       9719
# 90.0       3104
# 360.0      2176
# 65.0       2135
# Name: angle, dtype: int64

# %% [markdown]
# Смотрим распределение радиусов действия БС

# %%
plt.hist(df_data['max_dist'].values, bins=30)
plt.xticks(rotation=70)
plt.show()
df_data['max_dist'].describe()
# Out:
# count    174074.000000
# mean       1101.883917
# std         849.705447
# min           1.000000
# 25%         532.000000
# 50%        1104.000000
# 75%        1251.000000
# max       15661.000000
# Name: max_dist, dtype: float64

# %% [markdown]
# # Преобразование координат для создания параметров по координатам

# %% [markdown]
# Для событий определяю координаты прямоугольника, в котором действует БС, и где событие могло произойти.

# %%
df_data_copy = df_data.copy()
df_data = BS_rectangle_coordinate(df_data_copy, CENTER_LAT, CENTER_LONG)

# %% [markdown]
# Теперь строим две таблицы с информацией о расположение абноента в определнные временные срезы.
# В первой таблице для каждого отрезка времени мы определяем расположение как среднее по всем событиям этого отрезка.
# Если событий в этом отрезке не было, то оцениваем координаты как линейную комбинацию ближайших окружающих точек. Тут для каждого интервала определяется координаты.
#
# Во второй таблице мы оцениваем расположение только по событиям, которые произошли в ограниченном инервале времени. То есть на координаты влияют только ближайшие события. Если в зааднном интервале времени событий не произошло, то мы не можем определить координаты.

# %% [markdown]
# # Создание таблицы `ln`

# %%
# разбиваем время на BINS_QNT равных интервалов
BINS_QNT_LN = 150
df_data_bin_ln, bins_list_ln = CreateTimeBeans(df_data, BINS_QNT_LN)

# создаем декартовое произведение абонентов и интервалов. Затем эту таблицу мы дополним подобранными координатами
df_data_pivot_base_ln = CreatePivotBase(df_data_bin_ln)

# агрегируем зарегистрированные события по интервалам времени.
# Для интервалов с событиями определяем среднее расположения квадрата действия БС
df_data_bin_agg_ln = AggData(df_data_bin_ln)

# линейно апроксиммируем координаты в интервалах, в которых не было событий
df_data_agg_for_pivot_ln = LinearCombData(df_data_pivot_base_ln, df_data_bin_agg_ln)

# таблица с инфомрацией об одном абоненте
df_data_agg_pivot_ln = CreatePivot(df_data_agg_for_pivot_ln)

# %% [markdown]
# # Создание таблицы `shift`

# %%
BINS_QNT_SHIFT = 75

# таблицу дополняем N сдвигами на DELTA минут
DELTA, N = 30, 2
df_data_shift = AddDataDelta(df_data, DELTA, N)

# разбиваем время на BINS_QNT равных интервалов
df_data_bin_shift, bins_list_shift = CreateTimeBeans(df_data_shift, BINS_QNT_SHIFT)

# создаем декартовое произведение абонентов и интервалов. Затем эту таблицу мы дополним подобранными координатами
df_data_pivot_base_shift = CreatePivotBase(df_data_bin_shift)

# агрегируем зарегистрированные события по интервалам времени.
# Для интервалов с событиями определяем среднее расположения квадрата действия БС
df_data_bin_agg_shift = AggData(df_data_bin_shift)

# Дополняем подобранные координаты к декартовому произведению абонентов и интервалов
df_data_agg_for_pivot_shift = CombData(df_data_pivot_base_shift, df_data_bin_agg_shift)

df_data_agg_pivot_shift = CreatePivot(df_data_agg_for_pivot_shift)

# %% [markdown]
# Создаем таблицу со списком пар абонентов, на которой мы будем проводить обучение

# %%
# В таблицу попадают все пары из таблицы Факты, PAIR_RANDOM_SHARE пар, у которых только один номер из таблицу Факты
# RANDOM_RANDOM_SHARE пар, у которых только один номер из таблицы Факты

PAIR_RANDOM_SHARE = 0.3
RANDOM_RANDOM_SHARE = 0.0

df_msisdn_pairs = CreateMsisdnPairs(facts, df_data, PAIR_RANDOM_SHARE, RANDOM_RANDOM_SHARE)
# Out:
# Sample pairs: 122
# Pair Random pairs: 154548
# (154670, 3)
# ipynb.fs.full.persona_msisdn_functions:303: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
# C:\Users\ekaterina.adischeva\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py:6692: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)

# %%
dist_ind_ln, coord_ind_ln, center_dist_ind_ln = True, False, False
dist_ind_shift, coord_ind_shift, center_dist_ind_shift = False, False, False
df_X_ln = CreateAndProcessPivot(df_msisdn_pairs, df_data_agg_pivot_ln, bins_list_ln, 'ln', dist_ind_ln, coord_ind_ln, center_dist_ind_ln, CENTER_LAT, CENTER_LONG)
df_X_shift = CreateAndProcessPivot(df_msisdn_pairs, df_data_agg_pivot_shift, bins_list_shift, 'shift', dist_ind_shift, coord_ind_shift, center_dist_ind_shift, CENTER_LAT, CENTER_LONG)
# Out:
# (152190, 148)
# (152190, 5)

# %%
df_X_devices = ProcessPhoneFeaturesPivot(msisdn_device, df_msisdn_pairs, df_data)

# %%
df_X = pd.concat([df_X_shift, df_X_ln, df_X_devices], axis = 1)
df_X.reset_index(inplace = True)

# %%
df_X.head()
# Out:
#    is_pair      msisdn_x      msisdn_y  dist_mean_shift  intersect_mean_shift  \
# 0        0  158500002513  158500411793              NaN                   0.0
# 1        0  158500002513  158503536671              NaN                   0.0
# 2        0  158500002513  158504104657        99.359460                   0.0
# 3        0  158500002513  158504562579       112.769924                   0.0
# 4        0  158500002513  158505653139        60.971486                   0.0
#
#    intersect_count_shift  center_dist_x_mean_shift  center_dist_y_mean_shift  \
# 0               0.000000                 72.210841                 51.487027
# 1               0.000000                 72.210841                 12.470404
# 2               0.083333                 72.210841                 32.358372
# 3               0.097222                 72.210841                 43.889815
# 4               0.069444                 72.210841                 13.427031
#
#     7_dist_ln   8_dist_ln   9_dist_ln  10_dist_ln  11_dist_ln  12_dist_ln  \
# 0   64.466419   64.466419   64.466419   64.466419   64.466419   64.466419
# 1   66.302854   66.302854   66.302854   66.302854   66.302854   66.302854
# 2  101.671594  101.671594  101.671594  101.671594  101.671594  101.671594
# 3  112.155601  112.155601  112.155601  112.155601  112.155601  112.155601
# 4   60.442164   60.442164   60.442164   60.442164   60.442164   60.442164
#
#    13_dist_ln  14_dist_ln  15_dist_ln  16_dist_ln  17_dist_ln  18_dist_ln  \
# 0   64.466419   64.466419   64.466419   64.466419   64.466419   64.466419
# 1   66.302854   66.302854   66.302854   66.302854   66.302854   66.302854
# 2  101.671594  101.671594  101.671594  101.671594  101.671594  101.671594
# 3  112.155601  112.155601  112.155601  112.155601  112.155601  112.155601
# 4   60.442164   60.442164   60.442164   60.442164   60.442164   60.442164
#
#    19_dist_ln  20_dist_ln  21_dist_ln  22_dist_ln  23_dist_ln  24_dist_ln  \
# 0   64.466419   64.466419   64.466419   64.466419   64.466419   64.466419
# 1   66.302854   66.302854   66.302854   66.302854   66.302854   66.302854
# 2  101.671594  101.671594  101.671594  101.671594  101.671594  101.671594
# 3  112.155601  112.155601  112.155601  112.155601  112.155601  112.318060
# 4   60.442164   60.442164   60.442164   60.442164   60.442164   60.442164
#
#    25_dist_ln  26_dist_ln  27_dist_ln  28_dist_ln  29_dist_ln  30_dist_ln  \
# 0   64.466419   64.466419   64.466419   64.466419   64.466419   64.466419
# 1   66.302854   66.302854   66.302854   66.302854   66.302854   66.302854
# 2  101.671594  101.671594  101.671594  101.671594  101.671594  101.671594
# 3  112.480588  112.643183  112.805847  112.968579  113.131378  113.294244
# 4   60.467438   60.492712   60.517987   60.543261   60.568535   60.593810
#
#    31_dist_ln  32_dist_ln  33_dist_ln  34_dist_ln  35_dist_ln  36_dist_ln  \
# 0   64.466419   64.466419   64.466419   64.466419   64.466419   64.466419
# 1   66.302854   66.302854   66.302854   66.302854   66.302854   66.302854
# 2  101.671594  101.671594  101.532147  101.393405  101.255372  101.118051
# 3  113.457176  113.620176  113.410617  113.201169  112.991832  112.782605
# 4   60.619084   60.644359   60.669633   60.694908   60.720183   60.745458
#
#    37_dist_ln  38_dist_ln  39_dist_ln  40_dist_ln  41_dist_ln  42_dist_ln  \
# 0   64.466419   64.466419   64.466419   64.466419   64.466419   64.466419
# 1   66.302854   66.302854   66.302854   66.302854   66.302854   66.302854
# 2  100.981443  101.185943  101.392462  101.600989  101.602670  101.604351
# 3  112.573491  112.364489  112.155601  112.317938  112.480316  112.642733
# 4   60.770732   60.796007   60.821282   60.846557   60.871832   60.897107
#
#    43_dist_ln  44_dist_ln  45_dist_ln  46_dist_ln  47_dist_ln  48_dist_ln  \
# 0   64.466419   64.466419   64.466419   64.466419   64.118264   64.070298
# 1   66.302854   66.302854   66.302854   66.302854   66.302854   66.302854
# 2  101.606032  101.607713  101.609394  101.611075  101.612756  101.614437
# 3  112.805191  112.967688  113.130225  113.292801  113.598019  113.903348
# 4   60.922382   60.947657   60.972933   60.998208   61.023483   61.048759
#
#    49_dist_ln  50_dist_ln  51_dist_ln  52_dist_ln  53_dist_ln  54_dist_ln  \
# 0   64.025848   63.984922   63.947526   63.770396   63.597674   63.597674
# 1   66.302854   66.302854   66.302854   66.302854   66.302854   66.302854
# 2  101.616118  101.617799  101.619480  101.621161  101.622842  101.624524
# 3  114.208785  114.514331  113.334044  112.155601  112.224869  112.294144
# 4   61.074034   61.099310   61.060653   61.021997   60.983340   60.944684
#
#    55_dist_ln  56_dist_ln  57_dist_ln  58_dist_ln  59_dist_ln  60_dist_ln  \
# 0   63.597674   63.597674   63.597674   63.597674   63.597674   63.597674
# 1   66.302854   66.302854   66.302854   66.302854   66.302854   66.302854
# 2  101.626205  101.627886  101.629567  101.631248  101.632929  101.634610
# 3  112.363425  112.432712  112.502007  112.571308  112.640615  112.709929
# 4   60.906028   60.867372   60.828716   60.790060   60.751405   60.712749
#
#    61_dist_ln  62_dist_ln  63_dist_ln  64_dist_ln  65_dist_ln  66_dist_ln  \
# 0   63.597674   63.597674   63.597674   63.597674   63.597674   63.597674
# 1   66.302854   66.302854   66.302854   66.302854   66.302854   66.302854
# 2  101.636291  101.637972  101.639653  101.641334  101.643015  101.644696
# 3  112.779249  112.848576  112.917909  112.987249  113.056595  113.125947
# 4   60.674094   60.635438   60.596783   60.558128   60.519473   60.480819
#
#    67_dist_ln  68_dist_ln  69_dist_ln  70_dist_ln  71_dist_ln  72_dist_ln  \
# 0   63.597674   63.597674   63.597674   63.597674   63.597674   63.597674
# 1   66.302854   66.302854   66.302854   66.302854   66.302854   66.302854
# 2  101.646377  101.648058  101.649740  101.651421  101.653102  101.654783
# 3  113.195306  113.264672  113.334044  113.403422  113.472806  113.542197
# 4   60.442164   60.514740   60.587317   60.659894   60.732472   60.805050
#
#    73_dist_ln  74_dist_ln  75_dist_ln  76_dist_ln  77_dist_ln  78_dist_ln  \
# 0   63.597674   63.597674   63.597674   63.597674   63.597674   63.597674
# 1   66.302854   66.302854   66.302854   66.302854   66.302854   66.302854
# 2  101.656464  101.658145  101.659826  101.661507  101.663188  101.664869
# 3  113.611594  113.680998  113.750408  113.819824  113.889247  113.958675
# 4   60.877629   60.950208   61.022787   61.095367   61.045120   60.994872
#
#    79_dist_ln  80_dist_ln  81_dist_ln  82_dist_ln  83_dist_ln  84_dist_ln  \
# 0   65.343974   63.947526   63.953272   63.959109   63.965035   63.971053
# 1   66.302854   66.302854   66.302854   66.302854   66.302854   66.302854
# 2  101.666550  101.668231  101.669913  101.671594   98.018873   94.389011
# 3  114.028111  114.097552  114.167000  114.236453  114.305914  114.375380
# 4   60.944625   60.894378   60.844131   60.793884   60.743638   60.693391
#
#    85_dist_ln  86_dist_ln  87_dist_ln  88_dist_ln  89_dist_ln  90_dist_ln  \
# 0   63.977160   63.983358   63.989647   63.996026   64.002495   64.009055
# 1   66.302854   66.302854   66.302854   66.302854   66.302854   66.302854
# 2   96.910068   98.913023  100.919653  100.918552  100.918973  100.920917
# 3  114.444852  114.514331  114.041998  113.569955  113.098206  112.626753
# 4   60.643145   60.592900   60.542654   60.492409   60.442164   61.672343
#
#    91_dist_ln  92_dist_ln  93_dist_ln  94_dist_ln  95_dist_ln  96_dist_ln  \
# 0   64.015704   64.022444   64.029275   64.036195   64.043206   63.953093
# 1   66.302854   66.302854   66.302854   66.302854   66.302854   66.271595
# 2  100.924384  100.929374  100.935886  101.262880  101.600989  101.571347
# 3  112.155601  112.941022  113.727271  114.514331  112.155601  113.305329
# 4   61.672343   61.672343   61.672343   61.672343   61.672343   61.616941
#
#    97_dist_ln  98_dist_ln  99_dist_ln  100_dist_ln  101_dist_ln  102_dist_ln  \
# 0   63.863009   63.772952   63.682922    63.592921    63.625887    63.658967
# 1   66.240482   66.209514   66.178692    66.148016    66.156074    66.164143
# 2  101.541780   97.758241   93.994715    93.760485    93.605504    93.450849
# 3  114.457778  112.130137  109.804754   111.541449   113.317983   114.263858
# 4   61.561662   61.218368   60.875541    60.819906    60.834534    60.849172
#
#    103_dist_ln  104_dist_ln  105_dist_ln  106_dist_ln  107_dist_ln  \
# 0    63.692159    63.725463    63.758880    63.405518    63.549238
# 1    66.172222    66.180310    66.200662    66.221016    66.241371
# 2    93.296522    93.142525    92.988860    92.835527    93.170146
# 3   114.395670   114.403042   114.180431   113.957822   113.735214
# 4    60.863818    60.878472    60.893135    60.907807    60.922487
#
#    108_dist_ln  109_dist_ln  110_dist_ln  111_dist_ln  112_dist_ln  \
# 0    63.530576    63.511972    63.493427    63.474942    63.456515
# 1    66.261727    66.282086    66.302445    66.322807    66.343170
# 2    93.504813    93.839527    94.174289    94.509097    94.843951
# 3   113.512608   113.290004   113.067401   112.844800   112.622201
# 4    60.937175    60.951872    60.966578    60.981292    60.996015
#
#    113_dist_ln  114_dist_ln  115_dist_ln  116_dist_ln  117_dist_ln  \
# 0    63.438147    63.464320    63.490494    63.516670    63.542847
# 1    66.363535    66.383901    66.404269    66.424638    66.445009
# 2    95.178850    95.513795    95.848784    96.183817    96.518894
# 3   112.399603   112.177007   111.954413   111.731821   111.509230
# 4    61.010746    61.025485    61.040233    61.054990    61.069755
#
#    118_dist_ln  119_dist_ln  120_dist_ln  121_dist_ln  122_dist_ln  \
# 0    63.569025    63.595205    63.595822    63.596439    63.597057
# 1    66.465382    66.485756    66.497979    66.510205    66.522435
# 2    96.854014    97.189176    97.507467    97.825776    98.144103
# 3   111.286641   111.064054   110.834149   110.604258   110.374382
# 4    61.084528    61.099310    61.099310    61.099310    61.099310
#
#    123_dist_ln  124_dist_ln  125_dist_ln  126_dist_ln  127_dist_ln  \
# 0    63.597674    63.793926    63.804760    63.816136    63.828054
# 1    66.534669    66.546906    66.559147    66.571391    66.583639
# 2    98.462449    98.780814    99.099196    99.417596    99.736014
# 3   110.144521   109.914675   110.127205   110.339743   110.552287
# 4    61.099310    61.099310    61.099310    61.099310    61.099310
#
#    128_dist_ln  129_dist_ln  130_dist_ln  131_dist_ln  132_dist_ln  \
# 0    63.840514    63.853515    64.100964    63.746151    64.054196
# 1    66.595891    66.608146    66.620405    66.632668    66.644934
# 2   100.054450   100.372903   100.691373   100.443293   100.688086
# 3   110.764839   110.977397   111.189962   111.402534   111.615113
# 4    61.099310    61.099310    61.099310    61.099310    61.099310
#
#    133_dist_ln  134_dist_ln  135_dist_ln  136_dist_ln  137_dist_ln  \
# 0    64.056748    64.059371    64.062065    64.064830    64.067667
# 1    66.657204    66.669477    66.681754    66.694035    66.706319
# 2   100.932890   101.177707   101.234778   101.294663   101.600989
# 3   111.827699   112.040291   112.252890   112.465496   112.498764
# 4    61.099310    61.099310    61.099310    61.099310    61.099310
#
#    138_dist_ln  139_dist_ln  140_dist_ln  141_dist_ln  142_dist_ln  \
# 0    64.070574    64.203325    64.000144    63.798257    63.597674
# 1    66.718607    66.698874    66.679154    66.659446    66.639750
# 2   101.535735   101.470882   101.406429   101.342378   101.278729
# 3   112.532043   112.565333   112.598634   112.631947   112.665270
# 4    61.099310    61.099310    61.099310    61.099310    61.099310
#
#    143_dist_ln  144_dist_ln  145_dist_ln  146_dist_ln  147_dist_ln  \
# 0    64.000399    64.047921    64.096373    64.145752    64.196056
# 1    66.620067    66.600396    66.580737    66.561091    66.541457
# 2   101.215483   101.152642   100.453289    99.754467    99.056185
# 3   112.698604   112.731950   112.765306   112.798674   112.832052
# 4    61.099310    61.099310    61.099310    61.099310    61.099310
#
#    148_dist_ln  149_dist_ln  dist_mean_ln  intersect_mean_ln  \
# 0    64.247284    64.299433     63.985750                0.0
# 1    66.521835    66.502225     66.363522                0.0
# 2    98.358455    97.661290    100.053632                0.0
# 3   112.865442   112.898842    112.706552                0.0
# 4    61.099310    61.099310     60.877528                0.0
#
#    intersect_count_ln  center_dist_x_mean_ln  center_dist_y_mean_ln  imei_x  \
# 0                 1.0              72.229803              51.483242       1
# 1                 1.0              72.229803              12.393624       1
# 2                 1.0              72.229803              33.150540       1
# 3                 1.0              72.229803              43.757039       1
# 4                 1.0              72.229803              13.522168       1
#
#   type_x vendor_x   platform_x  imei_y type_y vendor_y   platform_y  same_imei
# 0  Other    Other  Proprietary       1  Other  Samsung      Android        0.0
# 1  Other    Other  Proprietary       1  Other  Samsung        Other        0.0
# 2  Other    Other  Proprietary       1  Other    Nokia   Symbian OS        0.0
# 3  Other    Other  Proprietary       1  Other    Nokia   Symbian OS        0.0
# 4  Other    Other  Proprietary       1  Other  Samsung  Proprietary        0.0

# %%
def my_OneHotEncoder (df):
    for column_name in ['type_x', 'vendor_x', 'platform_x', 'type_y', 'vendor_y', 'platform_y']:
        df[column_name].fillna('Other', inplace = True)
    for feature in ['type_x', 'vendor_x', 'platform_x', 'type_y', 'vendor_y', 'platform_y']:
        for feature_value in df[feature].unique():
            column_name = feature + '_' + feature_value
            df[column_name] = (df[feature] == feature_value) * 1
        df.drop(columns = [feature], inplace = True)
    return df

# %%
df_X = my_OneHotEncoder(df_X)

# %%
X = df_X.drop(columns = ['msisdn_x', 'msisdn_y', 'is_pair']).fillna(0)
y = df_X['is_pair']

# %% [markdown]
# ## Построение модели

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

# %%
categorical_features = ['type_x', 'vendor_x', 'platform_x', 'type_y', 'vendor_y', 'platform_y']
categorical_transformer = OneHotEncoder(handle_unknown='ignore')

preprocessor = ColumnTransformer(
    transformers=[
        ('cat', categorical_transformer, categorical_features)])

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

param_grid = { 
   # 'n_estimators': [200, 500],
    'max_features': ['auto'],
    'max_depth' : [4, 6, 8],
   # 'criterion' :['gini', 'entropy']
}

rfc = RandomForestClassifier(random_state=42)

pipe = Pipeline(steps=[('preprocessor', preprocessor),
                       ('classifier', RandomForestClassifier(random_state=42))])

search = GridSearchCV(rfc, param_grid=param_grid, scoring = 'f1', cv = 3)
search.fit(X_train, y_train)

print("Best parameter (CV score=%0.3f):" % search.best_score_)
print(search.best_params_)
# Out:
# Best parameter (CV score=0.024):
# {'max_depth': 4, 'max_features': 'auto'}

# %%
y_test_predict_proba = search.predict_proba(X_test)
y_test_predict = search.predict(X_test)

# %%
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import plot_precision_recall_curve

disp = plot_precision_recall_curve(search, X_test, y_test)

# %%
from numpy import argmax
precision, recall, thresholds = precision_recall_curve(y_test, y_test_predict_proba[:,1])

#pyplot.plot([0, 1], [0.5, 0.5], linestyle='--')
plt.plot(recall, precision, marker='.')
# show the plot
plt.show()

fscore = (2 * precision * recall) / (precision + recall)
# locate the index of the largest f score
ix = argmax(fscore)
print('Best Threshold=%f, F-Score=%.3f' % (thresholds[ix], fscore[ix]))
# Out:
# Best Threshold=0.153803, F-Score=0.506

# %%
Cls_result = pd.DataFrame(y_test)
Cls_result['proba'] = y_test_predict_proba[:,1]
Cls_result['predict'] = y_test_predict
Cls_result =  Cls_result.join(df_X[['msisdn_x', 'msisdn_y']])

from sklearn.metrics import precision_score
from sklearn.metrics import recall_score

for alpha in np.arange(0., .5, .01):
    Cls_result['predict_alpha'] = np.where(Cls_result['proba']> alpha, 1, 0)
    #print(alpha, precision_score(Cls_result['is_pair'], Cls_result['predict_alpha']), recall_score(Cls_result['is_pair'], Cls_result['predict_alpha']))

Cls_result['predict_alpha'] = np.where(Cls_result['proba']> 0.05, 1, 0)
Cls_result.groupby(['is_pair', 'predict_alpha']).agg({'msisdn_x':'count', 'proba':'mean'}).reset_index()

# %% [markdown]
# # Применении модели

# %%
df_data_msisdn = pd.DataFrame(data = df_data['msisdn'].unique(), columns = ['msisdn'])

# %%
'''
df_data_msisdn_sample = df_data_msisdn
df_data_msisdn['K'] = 1
df_data_msisdn_sample['K'] = 1
df_data_msisdn_sample = df_data_msisdn.merge(df_data_msisdn_sample, on = ['K'])
df_data_msisdn_sample = df_data_msisdn_sample[df_data_msisdn_sample['msisdn_x'] < df_data_msisdn_sample['msisdn_y']]

df_data_msisdn_sample['is_pair'] = 0
    
df_X_ln_sample = CreateAndProcessPivot(df_data_msisdn_sample, df_data_agg_pivot_ln, bins_list_ln, 'ln', dist_ind_ln, coord_ind_ln, center_dist_ind_ln, CENTER_LAT, CENTER_LONG)
df_X_shift_sample = CreateAndProcessPivot(df_data_msisdn_sample, df_data_agg_pivot_shift, bins_list_shift, 'shift', dist_ind_shift, coord_ind_shift, center_dist_ind_shift, CENTER_LAT, CENTER_LONG)
df_X_devices_sample = ProcessPhoneFeaturesPivot(msisdn_device, df_data_msisdn_sample, df_data)
df_X_sample = pd.concat([df_X_shift_sample, df_X_ln_sample, df_X_devices_sample], axis = 1)

df_X_sample.reset_index(inplace = True)

df_X_sample = my_OneHotEncoder(df_X_sample)
    
for columns in pd.DataFrame(df_X.columns).append(pd.DataFrame(df_X_sample.columns)).drop_duplicates(keep = False)[0]:
        df_X_sample[columns] = 0 
    
X_sample = df_X_sample.drop(columns = ['msisdn_x', 'msisdn_y', 'is_pair']).fillna(0)
X_sample_predict_proba = search.predict_proba(X_sample)
    
df_X_sample['prediction'] = X_sample_predict_proba[:,1]
df_X_sample_result = df_X_sample_result.append(df_X_sample[['msisdn_x', 'msisdn_y', 'prediction']])
df_X_sample.shape
'''
# Out:
# "\ndf_data_msisdn_sample = df_data_msisdn\ndf_data_msisdn['K'] = 1\ndf_data_msisdn_sample['K'] = 1\ndf_data_msisdn_sample = df_data_msisdn.merge(df_data_msisdn_sample, on = ['K'])\ndf_data_msisdn_sample = df_data_msisdn_sample[df_data_msisdn_sample['msisdn_x'] < df_data_msisdn_sample['msisdn_y']]\n\ndf_data_msisdn_sample['is_pair'] = 0\n    \ndf_X_ln_sample = CreateAndProcessPivot(df_data_msisdn_sample, df_data_agg_pivot_ln, bins_list_ln, 'ln', dist_ind_ln, coord_ind_ln, center_dist_ind_ln, CENTER_LAT, CENTER_LONG)\ndf_X_shift_sample = CreateAndProcessPivot(df_data_msisdn_sample, df_data_agg_pivot_shift, bins_list_shift, 'shift', dist_ind_shift, coord_ind_shift, center_dist_ind_shift, CENTER_LAT, CENTER_LONG)\ndf_X_devices_sample = ProcessPhoneFeaturesPivot(msisdn_device, df_data_msisdn_sample, df_data)\ndf_X_sample = pd.concat([df_X_shift_sample, df_X_ln_sample, df_X_devices_sample], axis = 1)\n\ndf_X_sample.reset_index(inplace = True)\n\ndf_X_sample = my_OneHotEncoder(df_X_sample)\n    \nfor columns in pd.DataFrame(df_X.columns).append(pd.DataFrame(df_X_sample.columns)).drop_duplicates(keep = False)[0]:\n        df_X_sample[columns] = 0 \n    \nX_sample = df_X_sample.drop(columns = ['msisdn_x', 'msisdn_y', 'is_pair']).fillna(0)\nX_sample_predict_proba = search.predict_proba(X_sample)\n    \ndf_X_sample['prediction'] = X_sample_predict_proba[:,1]\ndf_X_sample_result = df_X_sample_result.append(df_X_sample[['msisdn_x', 'msisdn_y', 'prediction']])\ndf_X_sample.shape\n"

# %%
df_data_msisdn.shape
# Out:
# (2359, 1)

# %%
df_X_sample_result = pd.DataFrame()

REPEAT = 10
a =int(df_data_msisdn.shape[0] / REPEAT)
print(a)

for i in range(0, REPEAT + 2):
    print(i)
    df_data_msisdn_sample = df_data_msisdn.iloc[a*(i):(min((i+1)*a, df_data_msisdn.shape[0]))]
    df_data_msisdn['K'] = 1
    df_data_msisdn_sample['K'] = 1
    df_data_msisdn_sample = df_data_msisdn.merge(df_data_msisdn_sample, on = ['K'])
    df_data_msisdn_sample = df_data_msisdn_sample[df_data_msisdn_sample['msisdn_x'] < df_data_msisdn_sample['msisdn_y']]

    df_data_msisdn_sample['is_pair'] = 0
    
    df_X_ln_sample = CreateAndProcessPivot(df_data_msisdn_sample, df_data_agg_pivot_ln, bins_list_ln, 'ln', dist_ind_ln, coord_ind_ln, center_dist_ind_ln, CENTER_LAT, CENTER_LONG)
    df_X_shift_sample = CreateAndProcessPivot(df_data_msisdn_sample, df_data_agg_pivot_shift, bins_list_shift, 'shift', dist_ind_shift, coord_ind_shift, center_dist_ind_shift, CENTER_LAT, CENTER_LONG)
    df_X_devices_sample = ProcessPhoneFeaturesPivot(msisdn_device, df_data_msisdn_sample, df_data)
    df_X_sample = pd.concat([df_X_shift_sample, df_X_ln_sample, df_X_devices_sample], axis = 1)

    df_X_sample.reset_index(inplace = True)
    
    df_X_sample = my_OneHotEncoder(df_X_sample)
    
    for columns in pd.DataFrame(df_X.columns).append(pd.DataFrame(df_X_sample.columns)).drop_duplicates(keep = False)[0]:
        df_X_sample[columns] = 0 
    
    X_sample = df_X_sample.drop(columns = ['msisdn_x', 'msisdn_y', 'is_pair']).fillna(0)
    X_sample_predict_proba = search.predict_proba(X_sample)
    
    df_X_sample['prediction'] = X_sample_predict_proba[:,1]
    df_X_sample_result = df_X_sample_result.append(df_X_sample[['msisdn_x', 'msisdn_y', 'prediction']])
    df_X_sample.shape
# Out:
# 471
# 0
# C:\Users\ekaterina.adischeva\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-63-f0b3db31563e> in <module>
#      15     df_data_msisdn_sample['is_pair'] = 0
#      16
# ---> 17     df_X_ln_sample = CreateAndProcessPivot(df_data_msisdn_sample, df_data_agg_pivot_ln, bins_list_ln, 'ln', dist_ind_ln, coord_ind_ln, center_dist_ind_ln, CENTER_LAT, CENTER_LONG)
#      18     df_X_shift_sample = CreateAndProcessPivot(df_data_msisdn_sample, df_data_agg_pivot_shift, bins_list_shift, 'shift', dist_ind_shift, coord_ind_shift, center_dist_ind_shift, CENTER_LAT, CENTER_LONG)
#      19     df_X_devices_sample = ProcessPhoneFeaturesPivot(msisdn_device, df_data_msisdn_sample, df_data)
#
# ~\Documents\Scripts\BD_task\persona_msisdn_functions.ipynb in CreateAndProcessPivot(msisdn_pairs, data_agg_pivot, bins_list, identifier, dist_ind, coord_ind, center_dist_ind, CENTER_LAT, CENTER_LONG)
#     367     "    df_data_pivot_base = df_data_pivot_base.merge(df_data_agg, on = ['msisdn', 'datetime_bin'], how = 'left')\n",
#     368     "\n",
# --> 369     "    return df_data_pivot_base[['msisdn', 'datetime_bin', 'long', 'long_max', 'long_min', 'lat', 'lat_max', 'lat_min']]"
#     370    ]
#     371   },
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2938             indexer = np.where(indexer)[0]
#    2939
# -> 2940         data = self._take(indexer, axis=1)
#    2941
#    2942         if is_single_key:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in _take(self, indices, axis, is_copy)
#    3353         numpy.take
#    3354         """
# -> 3355         self._consolidate_inplace()
#    3356
#    3357         new_data = self._data.take(indices,
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in _consolidate_inplace(self)
#    5136             self._data = self._data.consolidate()
#    5137
# -> 5138         self._protect_consolidate(f)
#    5139
#    5140     def _consolidate(self, inplace=False):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in _protect_consolidate(self, f)
#    5125         """
#    5126         blocks_before = len(self._data.blocks)
# -> 5127         result = f()
#    5128         if len(self._data.blocks) != blocks_before:
#    5129             self._clear_item_cache()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in f()
#    5134
#    5135         def f():
# -> 5136             self._data = self._data.consolidate()
#    5137
#    5138         self._protect_consolidate(f)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\internals\managers.py in consolidate(self)
#     922         bm = self.__class__(self.blocks, self.axes)
#     923         bm._is_consolidated = False
# --> 924         bm._consolidate_inplace()
#     925         return bm
#     926
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\internals\managers.py in _consolidate_inplace(self)
#     927     def _consolidate_inplace(self):
#     928         if not self.is_consolidated():
# --> 929             self.blocks = tuple(_consolidate(self.blocks))
#     930             self._is_consolidated = True
#     931             self._known_consolidated = True
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\internals\managers.py in _consolidate(blocks)
#    1897     for (_can_consolidate, dtype), group_blocks in grouper:
#    1898         merged_blocks = _merge_blocks(list(group_blocks), dtype=dtype,
# -> 1899                                       _can_consolidate=_can_consolidate)
#    1900         new_blocks = _extend_blocks(merged_blocks, new_blocks)
#    1901     return new_blocks
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\internals\blocks.py in _merge_blocks(blocks, dtype, _can_consolidate)
#    3147
#    3148         argsort = np.argsort(new_mgr_locs)
# -> 3149         new_values = new_values[argsort]
#    3150         new_mgr_locs = new_mgr_locs[argsort]
#    3151
#
# MemoryError:

# %%
a,b =  df_X_sample_result.sample(n = 1).iloc[0][['msisdn_x', 'msisdn_y']]

print('Persona', a, b)
fig = plt.figure(figsize=(15, 4))
show_chart(fig, df_data[df_data['msisdn'] == a], df_data[df_data['msisdn'] == b])
plt.show()
fig = plt.figure(figsize=(15, 4))
show_chart(fig, df_data[df_data['msisdn'] == a], df_data[df_data['msisdn'] == b])
plt.show()

m = folium.Map(location=(55.7522200, 37.6155600)) 
show_circles_on_map(m, df_data[df_data['msisdn'] == a ], "lat", "long", "blue")
show_circles_on_map(m, df_data[df_data['msisdn'] == b ], "lat", "long", "red")
